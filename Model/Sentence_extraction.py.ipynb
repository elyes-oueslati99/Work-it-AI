# %%
# !python -m spacy download en_core_web_sm

# %%
from bs4 import BeautifulSoup
import os
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()
nlp = spacy.load('en_core_web_sm')

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
def get_sentences(PATH):
    '''For each paras.txt extract sentences for each paragraph using bs4.'''
    
    sent_file = open(os.path.join(PATH,'sentences.txt'),'w',encoding="utf-8")
    
    with open(os.path.join(PATH,'paras.txt'),encoding="utf-8") as fobj:
        #read the file line-by-line
        for line in fobj:
            if line != '\n' and line.strip().startswith('<p>'):
                try:
                    #extract tagless paragraph-text from <p> tags.
                    soup = BeautifulSoup(line.strip(),"lxml")
                    
                    #divide this tagless paragraphs into proper sentences using NLP via spacy.
                    doc = nlp(soup.p.text)
                except:
                    #If the line can't be parsed then log the line and continue to next line.
                    logging.warning(PATH,":",line,"can't be parsed.")
                    continue
                    
                #If parsed then write each sentence in the file 'sentences.txt'.
                for each in doc.sents:
                    text = each.text+'\n'
                    sent_file.write(each.text+'\n')
                    
    sent_file.close()

dirs = os.listdir('E:\s')
#print len(dirs)
for each in dirs:
    if each == '.DS_Store':
        continue
    PATH = os.path.join('E:\s',each)
    logging.info('Generating sentences for ' + each)
    get_sentences(PATH)
    logging.info('SUCCESS')
# Out:
# 2021-11-27 12:00:11,015 : INFO : Generating sentences for codegolf.meta.stackexchange.com
# 2021-11-27 12:18:59,776 : INFO : SUCCESS
# 2021-11-27 12:18:59,777 : INFO : Generating sentences for codereview.meta.stackexchange.com
# 2021-11-27 12:26:46,411 : INFO : SUCCESS
# 2021-11-27 12:26:46,413 : INFO : Generating sentences for coffee.meta.stackexchange.com
# 2021-11-27 12:26:59,710 : INFO : SUCCESS
# 2021-11-27 12:26:59,711 : INFO : Generating sentences for cogsci.stackexchange.com
# 2021-11-27 12:47:45,073 : INFO : SUCCESS
# 2021-11-27 12:47:45,075 : INFO : Generating sentences for computergraphics.meta.stackexchange.com
# 2021-11-27 12:48:02,839 : INFO : SUCCESS
# 2021-11-27 12:48:02,840 : INFO : Generating sentences for computergraphics.stackexchange.com
# 2021-11-27 13:23:42,971 : INFO : SUCCESS
# 2021-11-27 13:23:42,977 : INFO : Generating sentences for conlang.stackexchange.com
# 2021-11-27 13:25:25,677 : INFO : SUCCESS
# 2021-11-27 13:25:25,692 : INFO : Generating sentences for cooking.meta.stackexchange.com
# 2021-11-27 13:28:54,766 : INFO : SUCCESS
# 2021-11-27 13:28:54,768 : INFO : Generating sentences for craftcms.meta.stackexchange.com
# 2021-11-27 13:29:04,143 : INFO : SUCCESS
# 2021-11-27 13:29:04,145 : INFO : Generating sentences for crafts.meta.stackexchange.com
# 2021-11-27 13:29:54,025 : INFO : SUCCESS
# 2021-11-27 13:29:54,027 : INFO : Generating sentences for crypto.meta.stackexchange.com
# 2021-11-27 13:31:54,180 : INFO : SUCCESS
# 2021-11-27 13:31:54,181 : INFO : Generating sentences for cs.meta.stackexchange.com
# 2021-11-27 13:34:00,722 : INFO : SUCCESS
# 2021-11-27 13:34:00,724 : INFO : Generating sentences for cseducators.meta.stackexchange.com
# 2021-11-27 13:34:37,693 : INFO : SUCCESS
# 2021-11-27 13:34:37,694 : INFO : Generating sentences for cseducators.stackexchange.com
# 2021-11-27 13:44:35,288 : INFO : SUCCESS
# 2021-11-27 13:44:35,290 : INFO : Generating sentences for cstheory.meta.stackexchange.com
# 2021-11-27 13:46:46,996 : INFO : SUCCESS
# 2021-11-27 13:46:46,997 : INFO : Generating sentences for datascience.meta.stackexchange.com
# 2021-11-27 13:47:21,244 : INFO : SUCCESS
# 2021-11-27 13:47:21,245 : INFO : Generating sentences for dba.meta.stackexchange.com
# 2021-11-27 13:49:45,741 : INFO : SUCCESS
# 2021-11-27 13:49:45,742 : INFO : Generating sentences for devops.meta.stackexchange.com
# 2021-11-27 13:50:05,992 : INFO : SUCCESS
# 2021-11-27 13:50:05,993 : INFO : Generating sentences for devops.stackexchange.com
# 2021-11-27 14:01:56,985 : INFO : SUCCESS
# 2021-11-27 14:01:56,987 : INFO : Generating sentences for diy.meta.stackexchange.com
# 2021-11-27 14:04:07,898 : INFO : SUCCESS
# 2021-11-27 14:04:07,900 : INFO : Generating sentences for drones.meta.stackexchange.com
# 2021-11-27 14:04:27,365 : INFO : SUCCESS
# 2021-11-27 14:04:27,375 : INFO : Generating sentences for drones.stackexchange.com
# 2021-11-27 14:06:57,180 : INFO : SUCCESS
# 2021-11-27 14:06:57,181 : INFO : Generating sentences for earthscience.meta.stackexchange.com
# 2021-11-27 14:08:04,138 : INFO : SUCCESS
# 2021-11-27 14:08:04,139 : INFO : Generating sentences for ebooks.stackexchange.com
# 2021-11-27 14:12:02,289 : INFO : SUCCESS
# 2021-11-27 14:12:02,289 : INFO : Generating sentences for economics.stackexchange.com
# 2021-11-27 14:50:21,614 : INFO : SUCCESS
# 2021-11-27 14:50:21,617 : INFO : Generating sentences for elementaryos.meta.stackexchange.com
# 2021-11-27 14:50:34,310 : INFO : SUCCESS
# 2021-11-27 14:50:34,311 : INFO : Generating sentences for ell.meta.stackexchange.com
# 2021-11-27 14:54:58,968 : INFO : SUCCESS
# 2021-11-27 14:54:58,969 : INFO : Generating sentences for emacs.meta.stackexchange.com
# 2021-11-27 14:55:37,147 : INFO : SUCCESS
# 2021-11-27 14:55:37,148 : INFO : Generating sentences for engineering.meta.stackexchange.com
# 2021-11-27 14:56:22,963 : INFO : SUCCESS
# 2021-11-27 14:56:22,964 : INFO : Generating sentences for engineering.stackexchange.com
# 2021-11-27 15:31:49,077 : INFO : SUCCESS
# 2021-11-27 15:31:49,079 : INFO : Generating sentences for eosio.stackexchange.com
# 2021-11-27 15:37:11,471 : INFO : SUCCESS
# 2021-11-27 15:37:11,472 : INFO : Generating sentences for esperanto.stackexchange.com
# 2021-11-27 15:42:24,664 : INFO : SUCCESS
# 2021-11-27 15:42:24,665 : INFO : Generating sentences for expatriates.stackexchange.com
# 2021-11-27 16:00:29,956 : INFO : SUCCESS
# 2021-11-27 16:00:29,958 : INFO : Generating sentences for fitness.stackexchange.com
# 2021-11-27 16:41:23,596 : INFO : SUCCESS
# 2021-11-27 16:41:23,599 : INFO : Generating sentences for freelancing.meta.stackexchange.com
# 2021-11-27 16:41:49,965 : INFO : SUCCESS
# 2021-11-27 16:41:49,967 : INFO : Generating sentences for freelancing.stackexchange.com
# 2021-11-27 16:51:44,600 : INFO : SUCCESS
# 2021-11-27 16:51:44,602 : INFO : Generating sentences for french.meta.stackexchange.com
# 2021-11-27 16:52:43,834 : INFO : SUCCESS
# 2021-11-27 16:52:43,835 : INFO : Generating sentences for gardening.meta.stackexchange.com
# 2021-11-27 16:53:36,074 : INFO : SUCCESS
# 2021-11-27 16:53:36,075 : INFO : Generating sentences for genealogy.meta.stackexchange.com
# 2021-11-27 16:55:31,418 : INFO : SUCCESS
# 2021-11-27 16:55:31,419 : INFO : Generating sentences for german.meta.stackexchange.com
# 2021-11-27 16:57:26,865 : INFO : SUCCESS
# 2021-11-27 16:57:26,867 : INFO : Generating sentences for gis.meta.stackexchange.com
# 2021-11-27 17:01:04,594 : INFO : SUCCESS
# 2021-11-27 17:01:04,596 : INFO : Generating sentences for ham.meta.stackexchange.com
# 2021-11-27 17:01:37,564 : INFO : SUCCESS
# 2021-11-27 17:01:37,566 : INFO : Generating sentences for ham.stackexchange.com
# 2021-11-27 17:17:43,303 : INFO : SUCCESS
# 2021-11-27 17:17:43,304 : INFO : Generating sentences for health.meta.stackexchange.com
# 2021-11-27 17:19:17,332 : INFO : SUCCESS
# 2021-11-27 17:19:17,334 : INFO : Generating sentences for history.meta.stackexchange.com
# 2021-11-27 17:22:00,244 : INFO : SUCCESS
# 2021-11-27 17:22:00,246 : INFO : Generating sentences for homebrew.meta.stackexchange.com
# 2021-11-27 17:22:21,432 : INFO : SUCCESS
# 2021-11-27 17:22:21,433 : INFO : Generating sentences for interpersonal.meta.stackexchange.com
# 2021-11-27 17:27:18,578 : INFO : SUCCESS
# 2021-11-27 17:27:18,580 : INFO : Generating sentences for interpersonal.stackexchange.com
# 2021-11-27 18:18:30,484 : INFO : SUCCESS
# 2021-11-27 18:18:30,566 : INFO : Generating sentences for iota.meta.stackexchange.com
# 2021-11-27 18:18:37,114 : INFO : SUCCESS
# 2021-11-27 18:18:37,115 : INFO : Generating sentences for iota.stackexchange.com
# 2021-11-27 18:20:55,164 : INFO : SUCCESS
# 2021-11-27 18:20:55,166 : INFO : Generating sentences for italian.stackexchange.com
# 2021-11-27 18:34:39,443 : INFO : SUCCESS
# 2021-11-27 18:34:39,445 : INFO : Generating sentences for joomla.stackexchange.com
# 2021-11-27 18:51:34,166 : INFO : SUCCESS
# 2021-11-27 18:51:34,167 : INFO : Generating sentences for korean.meta.stackexchange.com
# 2021-11-27 18:51:46,767 : INFO : SUCCESS
# 2021-11-27 18:51:46,768 : INFO : Generating sentences for korean.stackexchange.com
# 2021-11-27 18:56:59,952 : INFO : SUCCESS
# 2021-11-27 18:56:59,954 : INFO : Generating sentences for law.meta.stackexchange.com
# 2021-11-27 18:58:30,006 : INFO : SUCCESS
# 2021-11-27 18:58:30,007 : INFO : Generating sentences for linguistics.stackexchange.com
# 2021-11-27 20:06:00,323 : INFO : SUCCESS
# 2021-11-27 20:06:00,324 : INFO : Generating sentences for literature.stackexchange.com
# 2021-11-27 20:35:24,187 : INFO : SUCCESS
# 2021-11-27 20:35:24,225 : INFO : Generating sentences for math.meta.stackexchange.com
# 2021-11-27 21:13:52,838 : INFO : SUCCESS
# 2021-11-27 21:13:52,840 : INFO : Generating sentences for matheducators.stackexchange.com
# 2021-11-27 21:38:35,442 : INFO : SUCCESS
# 2021-11-27 21:38:35,458 : INFO : Generating sentences for meta.askubuntu.com
# 2021-11-27 21:55:30,846 : INFO : SUCCESS
# 2021-11-27 21:55:30,898 : INFO : Generating sentences for movies.meta.stackexchange.com
# 2021-11-27 21:59:47,613 : INFO : SUCCESS
# 2021-11-27 21:59:47,614 : INFO : Generating sentences for musicfans.meta.stackexchange.com
# 2021-11-27 22:00:23,639 : INFO : SUCCESS
# 2021-11-27 22:00:23,640 : INFO : Generating sentences for musicfans.stackexchange.com
# 2021-11-27 22:07:15,732 : INFO : SUCCESS
# 2021-11-27 22:07:15,734 : INFO : Generating sentences for mythology.meta.stackexchange.com
# 2021-11-27 22:07:51,731 : INFO : SUCCESS
# 2021-11-27 22:07:51,732 : INFO : Generating sentences for networkengineering.meta.stackexchange.com
# 2021-11-27 22:09:03,494 : INFO : SUCCESS
# 2021-11-27 22:09:03,495 : INFO : Generating sentences for opendata.meta.stackexchange.com
# 2021-11-27 22:09:26,367 : INFO : SUCCESS
# 2021-11-27 22:09:26,369 : INFO : Generating sentences for opensource.meta.stackexchange.com
# 2021-11-27 22:10:17,522 : INFO : SUCCESS
# 2021-11-27 22:10:17,523 : INFO : Generating sentences for or.meta.stackexchange.com
# 2021-11-27 22:10:36,818 : INFO : SUCCESS
# 2021-11-27 22:10:36,819 : INFO : Generating sentences for outdoors.stackexchange.com
# 2021-11-27 22:41:34,458 : INFO : SUCCESS
# 2021-11-27 22:41:34,459 : INFO : Generating sentences for poker.stackexchange.com
# 2021-11-27 22:50:01,940 : INFO : SUCCESS
# 2021-11-27 22:50:01,941 : INFO : Generating sentences for portuguese.stackexchange.com
# 2021-11-27 22:58:25,073 : INFO : SUCCESS
# 2021-11-27 22:58:25,075 : INFO : Generating sentences for puzzling.meta.stackexchange.com
# 2021-11-27 23:03:08,476 : INFO : SUCCESS
# 2021-11-27 23:03:08,478 : INFO : Generating sentences for reverseengineering.stackexchange.com
